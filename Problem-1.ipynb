# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1D Random walk
#
# We will concider two kinds of 1D random talk.
# * $dx$ is uniformly distributed between $[-1/2, +1/2]$.
# * $dx=+1$ with probability 1/2 and $dx=-1$ with probability 1/2.
#
# For both kinds of the 1D random walk, you should do the following:
# * Plot a single trajectory.
# * Plot the histogram of the end point for an ensemble of trajectories.

# %% [markdown]
# ## $dx =   [−1/2,+1/2]$

# %%
import random 
import numpy as np 
import matplotlib.pyplot as plt 
dims = 1
step_n = 10000
step_set = [-1/2, 1/2]
origin = np.zeros((1,dims))
step_shape = (step_n,dims)
steps = np.random.choice(a=step_set, size=step_shape, p=[0.5, 0.5])

path = np.concatenate([origin, steps]).cumsum(0)
plt.plot(path)

# %%
dims = 1
path_end = []
for i in range(6000):  #6000 times
    step_n = 10000  #each time 10000 steps
    step_set = [-1/2, 1/2]
    origin = np.zeros((1,dims))
    step_shape = (step_n,dims)
    steps = np.random.choice(a=step_set, size=step_shape, p=[0.5, 0.5])
    path = np.concatenate([origin, steps]).cumsum(0)
    path_end.append(path[-1][0])
    
plt.hist(path_end)
# Out:
# (array([   5.,   21.,  185.,  776., 1711., 1873., 1039.,  327.,   55.,
#            8.]),
#  array([-213. , -171.5, -130. ,  -88.5,  -47. ,   -5.5,   36. ,   77.5,
#          119. ,  160.5,  202. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## $dx =   [−1,+1]$

# %%
dims = 1
step_n = 10000
step_set = [-1, 1]
origin = np.zeros((1,dims))
step_shape = (step_n,dims)
steps = np.random.choice(a=step_set, size=step_shape, p=[0.5, 0.5])

path = np.concatenate([origin, steps]).cumsum(0)
plt.plot(path)

# %%
dims = 1
path_end = []
for i in range(6000):  #6000 times
    step_n = 10000  #each time 10000 steps
    step_set = [-1, 1]
    origin = np.zeros((1,dims))
    step_shape = (step_n,dims)
    steps = np.random.choice(a=step_set, size=step_shape, p=[0.5, 0.5])
    path = np.concatenate([origin, steps]).cumsum(0)
    path_end.append(path[-1][0])
    
plt.hist(path_end)
# Out:
# (array([1.000e+00, 2.100e+01, 1.610e+02, 7.260e+02, 1.457e+03, 1.855e+03,
#         1.219e+03, 4.480e+02, 1.010e+02, 1.100e+01]),
#  array([-422. , -342.8, -263.6, -184.4, -105.2,  -26. ,   53.2,  132.4,
#          211.6,  290.8,  370. ]),
#  <a list of 10 Patch objects>)
